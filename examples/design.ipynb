# %% [markdown]
# # Mark 1 - Design

# %%
from tests.designs import mark1
from turbodesigner.exporter import TurbomachineryExporter
import pandas as pd

pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 150)

# %% [markdown]
# # Turbomachinery Properties

# %%
TurbomachineryExporter.turbomachinery_properties(mark1)
# Out:
#                                       0
# gamma (dimensionless)          1.400000
# cx (m/s)                     136.000000
# N (rpm)                    10000.000000
# Rs (J/(kgK))                 287.000000
# mdot (kg/s)                    4.374433
# PR (dimensionless)             2.880998
# P01 (Pa)                  101000.000000
# T01 (K)                      288.000000
# eta_isen (dimensionless)       0.878482
# eta_poly (dimensionless)       0.895038
# N_stg                          7.000000
# B_in (dimensionless)           0.000000
# B_out (dimensionless)          0.000000
# ht (dimensionless)             0.500000

# %% [markdown]
# # Stage Properties

# %%
TurbomachineryExporter.stage_properties(mark1)
# Out:
#    Stage  Delta_T0 (K)  R (dimensionless)  PR (dimensionless)  phi (dimensionless)  psi (dimensionless)
# 0      1     16.527045           0.866193            1.191007             1.573074             2.221088
# 1      2     16.527045           0.683097            1.180052             1.573074             2.221088
# 2      3     16.527045           0.500000            1.170284             1.573074             2.221088
# 3      4     16.527045           0.500000            1.161520             1.573074             2.221088
# 4      5     16.527045           0.500000            1.153612             1.573074             2.221088
# 5      6     16.527045           0.500000            1.146441             1.573074             2.221088
# 6      7     16.527045           0.500000            1.139910             1.573074             2.221088

# %% [markdown]
# # Stage Fluid Properties

# %%
TurbomachineryExporter.stage_fluid_properties(mark1)
# Out:
#    Stage     T01 (K)      T1 (K)  P01 (bar)  P1 (bar)  rho1 (kg/m^3)     T02 (K)      T2 (K)  P02 (bar)  P2 (bar)  rho2 (kg/m^3)
# 0      1  288.000000  275.244031   1.010000  0.861907       1.091090  304.527045  289.559643   1.202917  1.008389       1.213412
# 1      2  304.527045  292.977071   1.202917  1.050661       1.249532  321.054089  304.266638   1.419505  1.176260       1.346998
# 2      3  321.054089  310.460657   1.419505  1.262223       1.416601  337.581134  318.724179   1.661224  1.358492       1.485115
# 3      4  337.581134  326.987701   1.661224  1.485814       1.583256  354.108179  335.251224   1.929544  1.593218       1.655857
# 4      5  354.108179  343.514746   1.929544  1.734953       1.759788  370.635223  351.778268   2.225945  1.854140       1.836503
# 5      6  370.635223  360.041791   2.225945  2.011112       1.946262  387.162268  368.305313   2.551915  2.142736       2.027117
# ...

# %% [markdown]
# # Annulus

# %%
TurbomachineryExporter.annulus(mark1)
# Out:
#                   rh (m)    rt (m)    rm (m)
# Stage 1 Rotor   0.054143  0.110974  0.082558
#         Stator  0.057008  0.108109  0.082558
# Stage 2 Rotor   0.057746  0.107371  0.082558
#         Stator  0.059542  0.105575  0.082558
# Stage 3 Rotor   0.060672  0.104444  0.082558
#         Stator  0.061682  0.103435  0.082558
# Stage 4 Rotor   0.062976  0.102141  0.082558
#         Stator  0.063835  0.101282  0.082558
# Stage 5 Rotor   0.064941  0.100176  0.082558
#         Stator  0.065677  0.099440  0.082558
# Stage 6 Rotor   0.066629  0.098488  0.082558
#         Stator  0.067264  0.097853  0.082558
# Stage 7 Rotor   0.068089  0.097027  0.082558
#         Stator  0.068641  0.096475  0.082558

# %% [markdown]
# # Velocity Triangle

# %%
TurbomachineryExporter.velocity_triangle(mark1)
# Out:
#                               Hub        Mean         Tip
# Stage 1 cx (m/s)       136.000000  136.000000  136.000000
#         U (m/s)         56.698543   86.454917  116.211291
#         ctheta1 (m/s) -128.761244  -84.443721  -62.821563
#         c1 (m/s)       187.284430  160.083547  149.808374
#         wtheta1 (m/s) -185.459787 -173.573216 -179.032854
#         w1 (m/s)       229.981157  220.507735  224.830520
#         beta1 (deg)    -53.746934  -51.920199  -52.778348
#         alpha1 (deg)   -43.433884  -31.836548  -24.793313
#         ctheta2 (m/s) -128.761244  -84.443721  -62.821563
#         c2 (m/s)       187.284430  160.083547  149.808374
#         wtheta2 (m/s) -185.459787 -173.573216 -179.032854
#         w2 (m/s)       229.981157  220.507735  224.830520
#         beta2 (deg)    -53.746934  -51.920199  -52.778348
#         alpha2 (deg)   -43.433884  -31.836548  -24.793313
# Stage 2 cx (m/s)       136.000000  136.000000  136.000000
# ...

# %% [markdown]
# # Blade Angles

# %%
TurbomachineryExporter.blade_angles(mark1)
# Out:
#                             Hub       Mean        Tip
# Stage 1 kappa1 (deg) -53.746934 -51.920199 -52.778348
#         kappa2 (deg)  35.245523   8.829382 -12.863548
#         theta (deg)  -88.992457 -60.316841 -39.914800
#         xi (deg)      -9.250706 -21.329039 -32.820948
# Stage 2 kappa1 (deg) -49.381032 -49.057901 -50.536637
#         kappa2 (deg)  38.650614  15.201784  -5.899568
#         theta (deg)  -88.031646 -63.950092 -44.637069
#         xi (deg)      -5.365209 -16.773262 -28.218102
# Stage 3 kappa1 (deg) -44.865107 -45.674314 -48.010222
#         kappa2 (deg)  41.840562  21.212304   1.187997
#         theta (deg)  -86.705670 -66.886619 -49.198218
#         xi (deg)      -1.512273 -12.231005 -23.411112
# Stage 4 kappa1 (deg) -44.819576 -45.674314 -47.731286
#         kappa2 (deg)  39.780518  21.212304   3.129863
#         theta (deg)  -84.600094 -66.886619 -50.861149
#         xi (deg)      -2.519529 -12.231005 -22.300712
# ...

# %% [markdown]
# # Blade Properties

# %%
TurbomachineryExporter.blade_properties(mark1)
# Out:
#                 sc (dimensionless)  AR (dimensionless)  tbc (dimensionless)  sigma (dimensionless)     c (m)     h (m)
# Stage 1 Rotor                  1.0                3.00                  0.1                    1.0  0.018943  0.056830
#         Stator                 1.0                3.25                  0.1                    1.0  0.015724  0.051101
# Stage 2 Rotor                  1.0                3.00                  0.1                    1.0  0.016541  0.049624
#         Stator                 1.0                3.25                  0.1                    1.0  0.014164  0.046034
# Stage 3 Rotor                  1.0                3.00                  0.1                    1.0  0.014591  0.043772
#         Stator                 1.0                3.25                  0.1                    1.0  0.012847  0.041752
# Stage 4 Rotor                  1.0                3.00                  0.1                    1.0  0.013055  0.039164
# ...
