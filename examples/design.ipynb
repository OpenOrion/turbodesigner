# %% [markdown]
# # Mark 1 - Design

# %%
from tests.designs import mark1
from turbodesigner.exporter import TurbomachineryExporter
from turbodesigner.visualizer import TurbomachineryVisualizer
import pandas as pd
import numpy as np

pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 150)
pd.set_option('display.float_format', lambda x: '%.3f' % x)

# %% [markdown]
# # Turbomachinery Properties

# %%
TurbomachineryExporter.turbomachinery_properties(mark1)
# Out:
#                                  0
# gamma (dimensionless)        1.400
# cx (m/s)                   136.000
# N (rpm)                  10000.000
# Rs (J/(kgK))               287.000
# mdot (kg/s)                  4.374
# PR (dimensionless)           3.000
# Pt1 (bar)                    1.010
# Tt1 (K)                    288.000
# eta_isen (dimensionless)     0.878
# eta_poly (dimensionless)     0.896
# N_stg                        5.000
# B_in (dimensionless)         0.000
# B_out (dimensionless)        0.000
# ht (dimensionless)           0.500

# %% [markdown]
# # Stage Properties

# %%
TurbomachineryExporter.stage_properties(mark1)
# Out:
#    Stage  Delta_Tt (K)  Delta_ht (J/kg)  PR (dimensionless)  R (dimensionless)  phi (dimensionless)  psi (dimensionless)
# 0      1        24.177        24286.102               1.287              0.500                1.573                3.249
# 1      2        24.177        24286.102               1.263              0.500                1.573                3.249
# 2      3        24.177        24286.102               1.243              0.500                1.573                3.249
# 3      4        24.177        24286.102               1.226              0.500                1.573                3.249
# 4      5        24.177        24286.102               1.211              0.500                1.573                3.249

# %% [markdown]
# # Stage Fluid Properties

# %%
TurbomachineryExporter.stage_fluid_properties(mark1)
# Out:
#    Stage  Tt1 (K)  Pt1 (bar)  ht1 (J/kg*K)  T1 (K)  P1 (bar)     H1 (K)  rho1 (kg/m^3)  Tt2 (K)  Pt2 (bar)  ht2 (J/kg*K)  T2 (K)  P2 (bar)  \
# 0      1  288.000      1.010    289296.000 274.088     0.849 275321.374          1.080  312.177      1.300    313582.102 286.177     0.959
# 1      2  312.177      1.300    313582.102 298.265     1.109 299607.476          1.295  336.355      1.643    337868.205 310.354     1.240
# 2      3  336.355      1.643    337868.205 322.443     1.417 323893.578          1.531  360.532      2.042    362154.307 334.531     1.572
# 3      4  360.532      2.042    362154.307 346.620     1.779 348179.681          1.789  384.709      2.503    386440.409 358.709     1.959
# 4      5  384.709      2.503    386440.409 370.797     2.200 372465.783          2.068  408.887      3.030    410726.512 382.886     2.408
#
#       H2 (K)  rho2 (kg/m^3)
# 0 287464.425          1.168
# 1 311750.527          1.392
# 2 336036.629          1.637
# 3 360322.732          1.903
# 4 384608.834          2.191

# %% [markdown]
# # Annulus

# %%
TurbomachineryVisualizer.visualize_annulus(mark1)
TurbomachineryExporter.annulus(mark1)
# Out:
#                 rh (m)  rt (m)  rm (m)
# Stage 1 Rotor    0.054   0.111   0.083
#         Stator   0.056   0.109   0.083
# Stage 2 Rotor    0.059   0.106   0.083
#         Stator   0.060   0.105   0.083
# Stage 3 Rotor    0.062   0.103   0.083
#         Stator   0.064   0.101   0.083
# Stage 4 Rotor    0.065   0.100   0.083
#         Stator   0.066   0.099   0.083
# Stage 5 Rotor    0.068   0.098   0.083
#         Stator   0.068   0.097   0.083

# %% [markdown]
# # Velocity Triangle

# %%
TurbomachineryExporter.velocity_triangle(mark1)
# Out:
#                           Hub     Mean      Tip
# Stage 1 Vm (m/s)      136.000  136.000  136.000
#         U (m/s)        56.384   86.455  116.526
#         Vθ1 (m/s)    -149.082  -97.228  -72.137
#         V1 (m/s)      201.796  167.180  153.947
#         Wθ1 (m/s)    -205.466 -186.120 -188.663
#         W1 (m/s)      246.399  230.514  232.572
#         beta1 (deg)   -56.499  -53.844  -54.214
#         alpha1 (deg)  -47.627  -35.561  -27.942
#         Vθ2 (m/s)     270.751  183.683  138.987
#         V2 (m/s)      302.989  228.551  194.457
#         Wθ2 (m/s)     212.099   97.228   24.730
#         W2 (m/s)      251.956  167.180  138.230
#         beta2 (deg)    57.332   35.561   10.306
#         alpha2 (deg)   63.329   53.483   45.622
# Stage 2 Vm (m/s)      136.000  136.000  136.000
#         U (m/s)        61.385   86.455  111.525
#         Vθ1 (m/s)    -136.937  -97.228  -75.372
#         V1 (m/s)      192.997  167.180  155.489
#         Wθ1 (m/s)    -198.322 -185.117 -186.897
#         W1 (m/s)      240.473  229.705  231.141
#         beta1 (deg)   -55.559  -53.696  -53.958
#         alpha1 (deg)  -45.197  -35.561  -28.995
#         Vθ2 (m/s)     251.557  183.683  144.653
#         V2 (m/s)      285.967  228.551  198.546
#         Wθ2 (m/s)     188.430   97.228   34.871
#         W2 (m/s)      232.383  167.180  140.399
#         beta2 (deg)    54.180   35.561   14.381
#         alpha2 (deg)   61.603   53.483   46.766
# Stage 3 Vm (m/s)      136.000  136.000  136.000
#         U (m/s)        65.253   86.455  107.657
#         Vθ1 (m/s)    -128.819  -97.228  -78.080
#         V1 (m/s)      187.324  167.180  156.820
#         Wθ1 (m/s)    -194.072 -184.733 -185.737
#         W1 (m/s)      236.981  229.395  230.204
#         beta1 (deg)   -54.978  -53.640  -53.788
#         alpha1 (deg)  -43.447  -35.561  -29.861
#         Vθ2 (m/s)     238.370  183.683  149.406
#         V2 (m/s)      274.438  228.551  202.035
#         Wθ2 (m/s)     171.750   97.228   43.116
#         W2 (m/s)      219.076  167.180  142.671
#         beta2 (deg)    51.626   35.561   17.590
#         alpha2 (deg)   60.293   53.483   47.689
# Stage 4 Vm (m/s)      136.000  136.000  136.000
#         U (m/s)        68.305   86.455  104.605
#         Vθ1 (m/s)    -123.064  -97.228  -80.358
#         V1 (m/s)      183.414  167.180  157.966
#         Wθ1 (m/s)    -191.368 -184.531 -184.963
#         W1 (m/s)      234.772  229.233  229.581
#         beta1 (deg)   -54.600  -53.610  -53.674
#         alpha1 (deg)  -42.141  -35.561  -30.577
#         Vθ2 (m/s)     228.837  183.683  153.411
#         V2 (m/s)      266.200  228.551  205.015
#         Wθ2 (m/s)     159.442   97.228   49.897
#         W2 (m/s)      209.565  167.180  144.864
#         beta2 (deg)    49.537   35.561   20.148
#         alpha2 (deg)   59.277   53.483   48.443
# Stage 5 Vm (m/s)      136.000  136.000  136.000
#         U (m/s)        70.752   86.455  102.158
#         Vθ1 (m/s)    -118.807  -97.228  -82.283
#         V1 (m/s)      180.585  167.180  158.954
#         Wθ1 (m/s)    -189.559 -184.382 -184.441
#         W1 (m/s)      233.299  229.113  229.160
#         beta1 (deg)   -54.342  -53.588  -53.596
#         alpha1 (deg)  -41.140  -35.561  -31.175
#         Vθ2 (m/s)     221.680  183.683  156.805
#         V2 (m/s)      260.073  228.551  207.567
#         Wθ2 (m/s)     150.044   97.228   55.532
#         W2 (m/s)      202.507  167.180  146.900
#         beta2 (deg)    47.811   35.561   22.211
#         alpha2 (deg)   58.471   53.483   49.064

# %% [markdown]
# # Blade Angles

# %%
TurbomachineryExporter.blade_angles(mark1)
# Out:
#                                    Hub    Mean     Tip
# Stage 1 - Rotor  delta (deg)    -0.619  10.602  26.605
#                  i (deg)        -4.238   3.583  14.560
#                  kappa1 (deg)  -52.261 -57.067 -68.773
#                  kappa2 (deg)   57.951  24.959 -16.299
#                  theta (deg)  -110.212 -82.026 -52.475
#                  xi (deg)        2.845 -16.054 -42.536
# Stage 1 - Stator delta (deg)   -14.492 -10.602  -8.264
#                  i (deg)        -7.775  -3.583  -1.549
#                  kappa1 (deg)   71.104  57.067  47.171
#                  kappa2 (deg)  -30.705 -24.959 -20.732
#                  theta (deg)   101.809  82.026  67.903
#                  xi (deg)       20.200  16.054  13.220
# Stage 2 - Rotor  delta (deg)     0.781  10.602  23.815
#                  i (deg)        -3.146   3.583  12.572
#                  kappa1 (deg)  -52.413 -57.067 -66.530
#                  kappa2 (deg)   53.399  24.959  -9.434
#                  theta (deg)  -105.812 -82.026 -57.095
#                  xi (deg)        0.493 -16.054 -37.982
# Stage 2 - Stator delta (deg)   -13.648 -10.602  -8.593
#                  i (deg)        -6.823  -3.583  -1.800
#                  kappa1 (deg)   68.426  57.067  48.566
#                  kappa2 (deg)  -29.798 -24.959 -21.268
#                  theta (deg)    98.224  82.026  69.833
#                  xi (deg)       19.314  16.054  13.649
# Stage 3 - Rotor  delta (deg)     1.988  10.602  21.681
#                  i (deg)        -2.260   3.583  11.077
#                  kappa1 (deg)  -52.719 -57.067 -64.864
#                  kappa2 (deg)   49.638  24.959  -4.090
#                  theta (deg)  -102.357 -82.026 -60.774
#                  xi (deg)       -1.540 -16.054 -34.477
# Stage 3 - Stator delta (deg)   -13.061 -10.602  -8.864
#                  i (deg)        -6.172  -3.583  -2.014
#                  kappa1 (deg)   66.466  57.067  49.704
#                  kappa2 (deg)  -29.080 -24.959 -21.714
#                  theta (deg)    95.546  82.026  71.417
#                  xi (deg)       18.693  16.054  13.995
# Stage 4 - Rotor  delta (deg)     3.016  10.602  20.016
#                  i (deg)        -1.529   3.583   9.924
#                  kappa1 (deg)  -53.070 -57.067 -63.598
#                  kappa2 (deg)   46.521  24.959   0.132
#                  theta (deg)   -99.591 -82.026 -63.730
#                  xi (deg)       -3.275 -16.054 -31.733
# Stage 4 - Stator delta (deg)   -12.633 -10.602  -9.087
#                  i (deg)        -5.705  -3.583  -2.197
#                  kappa1 (deg)   64.982  57.067  50.640
#                  kappa2 (deg)  -28.507 -24.959 -22.088
#                  theta (deg)    93.489  82.026  72.728
#                  xi (deg)       18.238  16.054  14.276
# Stage 5 - Rotor  delta (deg)     3.890  10.602  18.695
#                  i (deg)        -0.922   3.583   9.018
#                  kappa1 (deg)  -53.421 -57.067 -62.614
#                  kappa2 (deg)   43.921  24.959   3.516
#                  theta (deg)   -97.342 -82.026 -66.131
#                  xi (deg)       -4.750 -16.054 -29.549
# Stage 5 - Stator delta (deg)   -12.013 -10.602  -9.425
#                  i (deg)        -5.132  -3.583  -2.443
#                  kappa1 (deg)   63.603  57.067  51.508
#                  kappa2 (deg)  -28.775 -24.959 -21.971
#                  theta (deg)    92.378  82.026  73.478
#                  xi (deg)       17.414  16.054  14.768

# %% [markdown]
# # Blade Properties

# %%
TurbomachineryExporter.blade_properties(mark1)
# Out:
#                 sc (dimensionless)  AR (dimensionless)  tbc (dimensionless)  sigma (dimensionless)  c (m)  h (m)
# Stage 1 Rotor                1.000               3.000                0.100                  1.000  0.019  0.057
#         Stator               1.000               3.250                0.100                  1.000  0.016  0.053
# Stage 2 Rotor                1.000               3.000                0.100                  1.000  0.016  0.048
#         Stator               1.000               3.250                0.100                  1.000  0.014  0.045
# Stage 3 Rotor                1.000               3.000                0.100                  1.000  0.013  0.040
#         Stator               1.000               3.250                0.100                  1.000  0.012  0.038
# Stage 4 Rotor                1.000               3.000                0.100                  1.000  0.012  0.035
#         Stator               1.000               3.250                0.100                  1.000  0.010  0.033
# Stage 5 Rotor                1.000               3.000                0.100                  1.000  0.010  0.030
#         Stator               1.000               3.250                0.100                  1.000  0.009  0.028
