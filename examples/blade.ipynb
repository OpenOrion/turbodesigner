# %%
from tests.designs import mark1
from turbodesigner.cad.blade import BladeCadModel
from jupyter_cadquery import show
import numpy as np

blade_row = mark1.stages[5].stator
blade_row.airfoils[0].visualize(50, 50)
blade_profile = BladeCadModel.blade_profile(blade_row.to_export())
show(blade_profile)
# Out:
# [14.1754003  14.48344368 14.7436807  14.9597513  15.13523821 15.273617
#  15.37821947 15.45220824 15.49856053]
# ...
